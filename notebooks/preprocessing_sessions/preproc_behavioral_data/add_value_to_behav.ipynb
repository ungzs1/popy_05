# %%
from popy.behavior_data_tools import *
from popy.io_tools import *

# %%
behav = load_behavior_yuri()
behav = add_stay_value(behav)

# save as 'behavior_data_to_clemence.pkl'
behav.to_pickle('behavior_data_to_clemence.pkl')
behav
# Out:
#         monkey session  trial_id  block_id  best_target  target  feedback
# 0       yu_DCZ      10         0         0            1     NaN       NaN  \
# 1       yu_DCZ      10         1         0            1     3.0       0.0
# 2       yu_DCZ      10         2         0            1     3.0       1.0
# 3       yu_DCZ      10         3         0            1     2.0       0.0
# 4       yu_DCZ      10         4         0            1     1.0       1.0
# ...        ...     ...       ...       ...          ...     ...       ...
# 23543  yu_sham      71       536        12            3     3.0       1.0
# 23544  yu_sham      71       537        12            3     3.0       1.0
# 23545  yu_sham      71       538        12            3     3.0       1.0
# 23546  yu_sham      71       539        12            3     3.0       1.0
# 23547  yu_sham      71       540        12            3     3.0       1.0
#
#        stay_value  stay_proba
# 0             NaN         NaN
# ...
