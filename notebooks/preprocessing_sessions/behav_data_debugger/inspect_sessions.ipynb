# %%
import pandas as pd

# %%
summary_path = 'C:\\ZSOMBI\\OneDrive\\PoPy\\data\\recordings_summary.csv'
data_path = 'C:\\ZSOMBI\\OneDrive\\PoPy\\data\\processed\\behavior.pkl'

# session column is string
summary = pd.read_csv(summary_path, dtype={'session': str})
data = pd.read_pickle(data_path)

# %%
# print full summary, all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# sort by monkey and session
summary.sort_values(by=['monkey', 'session'], inplace=True)


summary
# Out:
#     monkey recording_day session  depth  session_of_day position_MCC
# 7       ka    2020-07-01  010720   8388               1           ck  \
# 65      ka    2022-08-01  010822   6187               2           ef
# 68      ka    2022-09-01  010922   5583               3           ej
# 24      ka    2020-10-01  011020   6455               3           fh
# 54      ka    2022-06-02  020622   7081               1           em
# 44      ka    2022-03-03  030322   7180               2           fj
# 52      ka    2022-05-03  030522   6980               2           dq
# 14      ka    2020-08-03  030820   8215               2           dk
# 21      ka    2020-09-03  030920   8672               2           ep
# 37      ka    2021-03-04  040321   6000               2           dh
# 29      ka    2020-12-04  041220   7231               2           gi
# 48      ka    2022-04-05  050422   4941               2           fg
# 1       ka    2020-06-05  050620   6914               2           ej
# ...

# %% [markdown]
# sum
