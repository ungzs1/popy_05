# %% [markdown]
# # Intro
#
# This notebook tests the functions of single unit plotting to plot one session's rates and rasters

# %% [markdown]
# ---
# # Setup

# %%
##% imports
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from time import time

from popy.io_tools import load_behavior, load_neural_data
from popy.behavior_data_tools import add_stay_value, drop_time_fields, add_RL_values, add_switch_info, add_history_of_feedback
from popy.neural_data_tools import *
from popy.plotting.plotting_tools import plot_keypoints


from popy.config import COLORS, value_gradient
# fontsizes 8
plt.rcParams.update({'font.size': 8})

# %%
##% data tools
def get_data(monkey, session, mode='full_trial', n_extra_trials=(0, 0)):
    #neural_data = get_data(monkey, session, n_extra_trials=n_extra_trials)

    # get behavior data
    behav = load_behavior(monkey, session)
    # remove interrupted trials (fb is nan)
    behav = behav[behav['feedback'].notna()]
    behav = add_switch_info(behav, add_trials_since_switch=True, flip_coding=False, relative_to='next')  # add switch info
    #behav = add_value_function(behav, monkey=monkey, digitize=True, n_classes=4) # add value function
    behav = add_stay_value(behav, digitize=True, n_classes=4) # add value function
    behav = add_RL_values(behav, digitize=True, n_classes=4)  # add RL values
    behav = add_history_of_feedback(behav, num_trials=2, one_column=True)  # add history of feedback
    
    behav.dropna(subset=['stay_value', 'Q_1', 'Q_2', 'Q_3'], inplace=True)  # drop nans in value
    
    '''behav['next_target'] = behav['target'].shift(-1)  # shift the target by 1
    behav['feedback_t-1'] = behav['feedback'].shift(1)  # shift the feedback by 1
    behav['feedback_t-2'] = behav['feedback'].shift(2)  # shift the feedback by 1
    behav['feedback_t-3'] = behav['feedback'].shift(3)  # shift the feedback by 1'''
    # shift the value function by 1
    behav = drop_time_fields(behav)  

    # get neural data
    neural_data = load_neural_data(monkey, session, hz=1000)  # load neural data
    neural_data = remove_trunctuated_neurons(neural_data, mode='set_nan', delay_limit=20, print_usr_msg=True)  # set indices to nan

    neural_data = add_firing_rates(neural_data, 'gauss')  # add firing gauss
    neural_data = downsample_time(neural_data, 100)  # downsample neural data
    #neural_data = time_normalize_session(neural_data)  # normalize neural data in time
    
    # build dataset
    if mode == 'full_trial':
        neural_dataset = build_trial_dataset(neural_data, mode='full_trial', n_extra_trials=n_extra_trials)
    elif mode == 'centering':
        neural_dataset = build_trial_dataset(neural_data, mode='centering', center_on_epoch_start=5, center_window=(-3, 3))

    print(f'Built dataset, shape:')
    neural_dataset = merge_behavior(neural_dataset, behav)  # merge behavior and neural data

    return neural_data, neural_dataset
    
        
def add_mixed_coord(neural_data_original, groupped_by):
    '''
    Removes all the coords from the neural_data except the trial_id, and adds a new coord along the trials dimension. Only the 
    coords to plot will rest in the neural_data.

    E.g. groupped_by = 'value * target' -> under each target, look at the value levels.
    
    '''
    neural_data = neural_data_original.copy()
    
    groupped_by = groupped_by.split(' * ')

    if len(groupped_by) == 1:
        primary_labels = neural_data.coords[groupped_by[0]].data  # e.g. a vector of the value levels per trial
        neural_data.coords[f'*{groupped_by[0]}'] = ('trial_id', primary_labels)
        return neural_data
        
    elif len(groupped_by) == 2:
        '''
        E.g. groupped_by = 'value * target' -> under each target, look at the value levels.
        '''    
        
        # get the 
        primary_labels = neural_data.coords[groupped_by[0]].data  # e.g. a vector of the value levels per trial
        secondary_labels = neural_data.coords[groupped_by[1]].data  # e.g. a vector of the selected targets per trial
                
        # add new coord along the trials dimension
        unique_secondary_labels = np.unique(secondary_labels)  # e.g. the unique targets
        unique_secondary_labels = unique_secondary_labels[~np.isnan(unique_secondary_labels)]  # remove nans
        for secondary_label in unique_secondary_labels:
            coord_name = f'*{groupped_by[0]} | {groupped_by[1]}={str(secondary_label)}'  # e.g. target_1_value
            coord_values = [primary if secondary == secondary_label else np.nan for primary, secondary in zip(primary_labels, secondary_labels) ]
            neural_data.coords[coord_name] = ('trial_id', coord_values)
            print(f'Added coord {coord_name}, length: {len(coord_values)}')
        
    return neural_data

# %%
##% plotting tools

'''COLORS_value= [
    '#779ECC',  # Dark Pastel Blue
    '#9FC0DE',  # Pale Cerulean
    '#F2C894',  # Peach-Orange
    '#FFB347',  # Pastel Orange
    '#FF985A'   # Atomic Tangerine
]

COLORS_feedback = [
    'tab:red',
    'tab:green',
]
'''

def plot_spike_trains(neural_data, monkey, session):
    plt.imshow(neural_data.spike_trains, aspect='auto', cmap='Grays', interpolation='none')
    ylabel = [f'{unit}' for unit in neural_data.unit.values]
    xlabel = neural_data.time.values
    plt.yticks(np.arange(len(ylabel)), ylabel, fontsize=5)
    #plt.xticks(np.arange(0, len(xlabel), 100000), xlabel[::100000])

    # add lables and legend: white horizontal bar is no recording, black is recording
    plt.plot([0, 0], [0, 0], color='black', label='Recording', linewidth=5)
    plt.plot([0, 0], [0, 0], color='white', label='No recording', linewidth=5)
    plt.legend(loc='upper right')

    plt.grid(alpha=.2)

    plt.xlabel('Time (ms)')
    plt.ylabel('Neurons')
    plt.title(f'{monkey}_{session}')
    plt.show()

def plot_rates_with_raster(
    neural_data_original, 
    unit_name, 
    mode='full_trial',  # 'full_trial' or 'centering'
    n_extra_trials=(0, 0),  # number of extra trials to plot (in case of full_trial)
    title=None,
    time_window=None,  # time window to plot (relative to the time of the data)
    color_palette=None,  # color palette to use, 'feedback' or 'value'
    show_raster=True,
    paper_format=False,  # use paper format
    ):    
    '''
    Plot the raster plot and the firing rate of a unit, for each value level of the coord_names.
    
    Parameters
    ----------
    neural_data : xarray.Dataset
        The neural data.
    unit_name : str
        The name of the unit to plot.
    n_extra_trials : touple, optional
        The number of extra trials to plot. The default is (0, 0).
    title : str, optional
        The title of the plot. The default is None.
    time_window : tuple, optional
        The time window to plot. The default is None.

    Returns
    ------- 
    fig : matplotlib.figure.Figure
        The figure.
    axs : matplotlib.axes.Axes
        The axes.
    '''

    neural_data = neural_data_original.copy()
    neural_data = neural_data.sel({'unit': unit_name})  # select the unit of interest

    # get the coord names of interest and determine the number of plots to make
    coord_names = [coord_name for coord_name in neural_data.coords if coord_name[0] == '*']  # get the coord names of interest
    n_plots = len(coord_names)
    
    # Create figure and axes with no space between rows
    if paper_format:
        # fontsize 8
        plt.rcParams.update({'font.size': 8})  # set fontsize to 8
        h, w = 1, 1.5 * n_plots  # 3 cm height, 3 cm width per plot
        fig = plt.figure(figsize=(w, h))
    else:
        h, w = 4, 4*n_plots
        fig = plt.figure(figsize=(w, h))
    
    gs = fig.add_gridspec(2, n_plots, height_ratios=[1, 1], hspace=0)

    # Create axes arrays with shared axes
    axs = [[None for j in range(n_plots)] for i in range(2)]
    
    # First create the leftmost column
    axs[0][0] = fig.add_subplot(gs[0, 0])  # Top left
    axs[1][0] = fig.add_subplot(gs[1, 0], sharex=axs[0][0])  # Bottom left
    plt.setp(axs[0][0].get_xticklabels(), visible=False)  # Hide only the tick labels, keep ticks

    # Then create the rest sharing both x and y axes
    for j in range(1, n_plots):
        axs[0][j] = fig.add_subplot(gs[0, j], sharex=axs[0][0], sharey=axs[0][0])  # Top row
        axs[1][j] = fig.add_subplot(gs[1, j], sharex=axs[0][0], sharey=axs[1][0])  # Bottom row
        plt.setp(axs[0][j].get_xticklabels(), visible=False)  # Hide only the tick labels, keep ticks

    if not title is None:
        fig.suptitle(title, style='italic')

    for i, coord_name in enumerate(coord_names):
        # get the variable and the conditions
        variable = coord_name.split(' | ')[0][1:]
        condition = coord_name.split(' | ')[1] if len(coord_name.split(' | ')) > 1 else None


        unique_labels = np.unique(neural_data[coord_name].data)  # get the unique labels of all of the coords of interest
        unique_labels = unique_labels[~np.isnan(unique_labels)]  # remove nans
        
        if variable == 'feedback':
            COLORS_temp = COLORS
        elif variable == 'stay_value':
            COLORS_temp = value_gradient(len(unique_labels))
        else:
            COLORS_temp = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan']

        colors = {str(label): COLORS_temp[i] for i, label in enumerate(unique_labels)}  # color for each value level

        # prepare the data (sort trials by the coord_name, drop trials with nan labels)
        neural_data_temp = _prepare_data(neural_data, coord_name)

        time_vector = neural_data_temp.coords['time'].data  # get the time vector and the trial labels

        # plot raster with extent of x=time_vector and y=trial_labels
        ax_raster = axs[0][i] if n_plots > 1 else axs[0][0]

        
        # Plot colored spikes
        if show_raster:
            # Convert spike trains to x,y coordinates
            spikes = np.where(neural_data_temp.spike_trains)
            trial_ids = spikes[0]
            spike_times = time_vector[spikes[1]]

            # Get colors for each spike based on trial type
            trial_colors = [colors[str(neural_data_temp[coord_name].sel(trial_id=neural_data_temp.trial_id.data[tid]).data)] for tid in trial_ids]  # get the color of the trial

            ax_raster.scatter(spike_times, trial_ids, marker='|', c=trial_colors, s=2.5, linewidth=0.6)
        else:
            # remove subplot if no raster is shown
            axs[0][i].remove()

        # settings
        if not paper_format:
            if condition is None:
                ax_raster.set_title(f'CODING OF: {variable}')
            else:
                ax_raster.set_title(f'CODING OF: {variable}' + f'\nCONDITION: {condition}')
            
        ax_raster.set_ylabel('')
        '''ax_raster.set_xlabel('')  # remove x label from the raster plot
        ax_raster.set_xticks([])  # remove y ticks'''
        ax_raster.set_yticks([])  # remove y ticks
        #ax_raster.legend(title=f'{coord_name.split("--")[0][1:]}', loc='center left', bbox_to_anchor=(1, 0.5))
        ax_raster.spines['bottom'].set_visible(False)

        # plot firing rate (that is the mean spike count) by value level
        ax_rate = axs[1][i] if n_plots > 1 else axs[1][0]
        unique_labels_temp = np.unique(neural_data_temp[coord_name].data)  # set background color based on value level
        for label_temp in unique_labels_temp:
            curr_coord_ids = np.where(neural_data_temp[coord_name].data == label_temp)[0]  # get the non-nan indices
            curr_coord_trials = neural_data_temp.trial_id.data[curr_coord_ids]
            neural_data_currvalue = neural_data_temp.sel({'trial_id': curr_coord_trials})  # further select only the interesting units
            # rolling window spike count mean
            mean_rate = np.mean(neural_data_currvalue.firing_rates, axis=0)

            ax_rate.plot(time_vector, mean_rate, label=f'{label_temp}', color=colors[str(label_temp)])
            
        if not paper_format:
            ax_rate.set_ylabel('Firing rate (Hz)')
            ax_rate.set_xlabel('Time from feedback (s)')
            ax_rate.legend(title=variable, frameon=False, loc='upper right')
        # settings
        for ax in [ax_raster, ax_rate]:
            if mode == 'full_trial':
                plot_keypoints(ax, n_extra_trials=n_extra_trials)  # plot the extra trials
                ax.grid(axis='x', alpha=.8, color='grey', linestyle='--')
            elif mode == 'centering':
                ax.axvline(0, color='black', lw=.7)  # plot the centering line
    

            if time_window is None:
                ax.set_xlim(time_vector[0], time_vector[-1])
            else:
                ax.set_xlim(*time_window)
            # remove spines
            for spine in ['right', 'top']:
                ax.spines[spine].set_visible(False)

    if not paper_format:    
        plt.tight_layout()

    return fig, axs


def _prepare_data(neural_data, coord_name):
        neural_data_temp = neural_data.copy()
        
        # get only the trials where the coord_name is not nan, and sort them
        non_nan_coord_ids = np.where(~np.isnan(neural_data_temp[coord_name].data))[0]  # get the non-nan indices
        non_nan_coord_trials = neural_data_temp.trial_id.data[non_nan_coord_ids]  # get the non-nan trials
        non_nan_coord_labels = neural_data_temp[coord_name].data[non_nan_coord_ids]  # get the non-nan labels
        non_nan_coord_trials = non_nan_coord_trials[np.argsort(non_nan_coord_labels)]  # sort the trials by the labels
        neural_data_temp = neural_data_temp.sel({'trial_id': non_nan_coord_trials})  # remove nan values (nan coordinates) and sort the trials by the labels

        # get only tials where the neural activity has no nan values - THIS SHOULD BE DONE BEFORE PASSING THE DATA TO THE PLOTTING FUNCTION
        """non_nan_ids = np.where(~np.isnan(neural_data_temp.spike_trains.data).all(axis=1))[0]
        non_nan_trials = neural_data_temp.trial_id.data[non_nan_ids]
        neural_data_temp = neural_data_temp.sel({'trial_id': non_nan_trials})"""  # remove nan values (nan neural activity)
    
        return neural_data_temp

# %% [markdown]
# ---
# # Load data

# %%
sessions = ['ka_160620_MCC_08_01',
 'ka_120820_MCC_16_02',
 'ka_240820_MCC_14_02',
 'ka_081020_MCC_10_01',
 'ka_180121_LPFC_11_01',
 'ka_180121_MCC_07_01',
 'ka_150221_MCC_06_01',
 'ka_150221_MCC_07_02',
 'ka_290921_MCC_14_02',
 'ka_190821_LPFC_08_03',
 'ka_030322_LPFC_05_03',
 'ka_210322_MCC_04_01',
 'ka_210322_MCC_08_03',
 'ka_210322_MCC_08_01',
 'ka_210322_MCC_16_03',
 'ka_280322_MCC_02_04',
 'ka_200422_LPFC_13_01',
 'ka_030522_MCC_08_01',
 'ka_030522_MCC_10_02',
 'ka_030522_MCC_12_01',
 'ka_020622_MCC_10_01',
 'ka_020622_MCC_12_01',
 'ka_150622_MCC_05_02',
 'po_070920_LPFC_04_02',
 'ka_060922_MCC_09_04',
 'ka_060922_MCC_09_02',
 'ka_300622_LPFC_04_05',
 'ka_210722_MCC_10_03',
 'ka_300822_LPFC_09_01',
 'po_140920_MCC_09_02',
 'po_150920_MCC_02_03',
 'po_121020_MCC_13_01',
 'po_160920_LPFC_04_01',
 'po_141020_LPFC_11_01',
 'po_141020_MCC_11_04',
 'po_141020_MCC_11_02',
 'po_210920_MCC_12_01',
 'po_261020_MCC_03_01',
 'po_011220_MCC_03_01',
 'po_031220_MCC_02_02',
 'po_031220_MCC_11_01',
 'po_120121_LPFC_07_01',
 'po_090421_MCC_11_02',
 'po_190121_LPFC_12_03',
 'po_071021_MCC_04_01',
 'po_230421_MCC_07_02',
 'po_230421_MCC_07_01',
 'po_090322_MCC_14_03',
 'po_180322_MCC_04_01',
 'po_220422_MCC_12_02',
 'po_140622_LPFC_06_01',
 'po_090822_MCC_11_01',
 'po_090822_MCC_16_02']

# %%
# convert list to df
df = []
for session in sessions:
    monkey, session, unit_name = session.split('_')[0], session.split('_')[1], session.split('_')[2] + '_' + session.split('_')[3] + '_' + session.split('_')[4]
    
    df.append({'monkey': monkey, 'session': session, 'unit_name': unit_name})
df = pd.DataFrame(df)
df
# Out:
#    monkey session   unit_name
# 0      ka  160620   MCC_08_01
# 1      ka  120820   MCC_16_02
# 2      ka  240820   MCC_14_02
# 3      ka  081020   MCC_10_01
# 4      ka  180121  LPFC_11_01
# 5      ka  180121   MCC_07_01
# 6      ka  150221   MCC_06_01
# 7      ka  150221   MCC_07_02
# 8      ka  290921   MCC_14_02
# 9      ka  190821  LPFC_08_03
# 10     ka  030322  LPFC_05_03
# 11     ka  210322   MCC_04_01
# 12     ka  210322   MCC_08_03
# 13     ka  210322   MCC_08_01
# 14     ka  210322   MCC_16_03
# 15     ka  280322   MCC_02_04
# 16     ka  200422  LPFC_13_01
# 17     ka  030522   MCC_08_01
# 18     ka  030522   MCC_10_02
# 19     ka  030522   MCC_12_01
# 20     ka  020622   MCC_10_01
# 21     ka  020622   MCC_12_01
# 22     ka  150622   MCC_05_02
# 23     po  070920  LPFC_04_02
# 24     ka  060922   MCC_09_04
# 25     ka  060922   MCC_09_02
# 26     ka  300622  LPFC_04_05
# 27     ka  210722   MCC_10_03
# 28     ka  300822  LPFC_09_01
# 29     po  140920   MCC_09_02
# 30     po  150920   MCC_02_03
# 31     po  121020   MCC_13_01
# 32     po  160920  LPFC_04_01
# 33     po  141020  LPFC_11_01
# 34     po  141020   MCC_11_04
# 35     po  141020   MCC_11_02
# 36     po  210920   MCC_12_01
# 37     po  261020   MCC_03_01
# 38     po  011220   MCC_03_01
# 39     po  031220   MCC_02_02
# 40     po  031220   MCC_11_01
# 41     po  120121  LPFC_07_01
# 42     po  090421   MCC_11_02
# 43     po  190121  LPFC_12_03
# 44     po  071021   MCC_04_01
# 45     po  230421   MCC_07_02
# 46     po  230421   MCC_07_01
# 47     po  090322   MCC_14_03
# 48     po  180322   MCC_04_01
# 49     po  220422   MCC_12_02
# 50     po  140622  LPFC_06_01
# 51     po  090822   MCC_11_01
# 52     po  090822   MCC_16_02

# %%
for (monkey, session), df_temp in df.groupby(['monkey', 'session']):
    neural_data, neural_dataset = get_data(monkey, session, mode='centering')

    #variable_of_interest = 'feedback'
    neural_data_proc = neural_dataset.copy()
    neural_data_proc = add_mixed_coord(neural_data_proc, 'history_of_feedback * feedback')
    
    for unit_name in df_temp['unit_name']:
        #for unit_name in neural_data_proc.unit.data:
        title = f'{neural_data_proc.coords["monkey"].data[0]}_{neural_data_proc.coords["session"].data[0]}_{unit_name}'
        fig, axs = plot_rates_with_raster(
            neural_data_proc, 
            unit_name, 
            mode='centering',
            #n_extra_trials=n_extra_trials, 
            title=title,
            time_window=(-.5, 2),
            show_raster=True,
            paper_format=False,  # use paper format
            )
            
        # save the figure in svg, 300 dpi
        fig.savefig(
            f'figs/rpe_units/{monkey}_{session}_{unit_name}.png',
            bbox_inches='tight',
            transparent=False,
            )
        plt.close(fig)
# Out:
# Set to NaN 4/40 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_15_03', 'MCC_03_01', 'MCC_08_02', 'MCC_08_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 341
# Added coord *history_of_feedback | feedback=1.0, length: 341
# Set to NaN 12/46 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_12_01', 'MCC_07_03', 'MCC_07_02', 'MCC_06_02', 'MCC_13_01', 'MCC_06_01', 'MCC_11_02', 'MCC_12_02', 'MCC_06_03', 'MCC_13_02', 'MCC_07_01', 'MCC_07_04'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 422
# Added coord *history_of_feedback | feedback=1.0, length: 422
# Set to NaN 33/51 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_14_04', 'MCC_15_03', 'LPFC_13_01', 'MCC_14_05', 'MCC_15_04', 'MCC_15_02', 'MCC_06_03', 'LPFC_13_03', 'MCC_12_01', 'MCC_05_02', 'MCC_12_02', 'MCC_03_01', 'MCC_02_02', 'MCC_14_01', 'MCC_02_03', 'MCC_06_01', 'LPFC_14_01', 'MCC_10_01', 'MCC_09_03', 'LPFC_13_04', 'MCC_14_03', 'MCC_01_01', 'MCC_05_01', 'MCC_09_02', 'LPFC_14_03', 'MCC_11_01', 'MCC_08_02', 'MCC_14_02', 'LPFC_11_02', 'LPFC_14_02', 'MCC_08_01', 'MCC_07_01', 'MCC_09_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 424
# Added coord *history_of_feedback | feedback=1.0, length: 424
# Set to NaN 5/35 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_13_03', 'LPFC_08_03', 'MCC_12_04', 'LPFC_06_04', 'MCC_14_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 382
# Added coord *history_of_feedback | feedback=1.0, length: 382
# Set to NaN 12/37 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_13_02', 'MCC_13_03', 'LPFC_15_02', 'LPFC_08_01', 'LPFC_15_01', 'MCC_06_01', 'LPFC_13_01', 'LPFC_14_01', 'MCC_15_02', 'LPFC_11_01', 'LPFC_13_03', 'LPFC_10_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 340
# Added coord *history_of_feedback | feedback=1.0, length: 340
# Set to NaN 19/28 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_09_04', 'MCC_16_04', 'MCC_07_02', 'MCC_16_03', 'MCC_01_03', 'MCC_03_01', 'MCC_02_01', 'MCC_04_01', 'MCC_09_03', 'MCC_01_01', 'MCC_09_02', 'MCC_01_04', 'MCC_07_03', 'MCC_16_02', 'MCC_08_02', 'MCC_08_03', 'MCC_16_01', 'MCC_01_02', 'MCC_09_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 470
# Added coord *history_of_feedback | feedback=1.0, length: 470
# Set to NaN 10/39 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_16_02', 'LPFC_10_02', 'MCC_07_03', 'LPFC_08_03', 'MCC_05_02', 'MCC_13_02', 'LPFC_16_03', 'MCC_05_03', 'MCC_05_01', 'MCC_07_04'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 422
# Added coord *history_of_feedback | feedback=1.0, length: 422
# Set to NaN 35/56 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC
units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_04_02', 'LPFC_07_01', 'LPFC_08_02', 'LPFC_10_02', 'LPFC_04_01', 'LPFC_16_02', 'LPFC_08_01', 'LPFC_15_01', 'LPFC_04_03', 'LPFC_10_03', 'LPFC_16_03'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 251
# Added coord *history_of_feedback | feedback=1.0, length: 251
# Set to NaN 8/26 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_16_02', 'MCC_15_01', 'MCC_06_02', 'MCC_14_02', 'MCC_12_03', 'MCC_08_01', 'MCC_05_03', 'MCC_04_03'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 468
# Added coord *history_of_feedback | feedback=1.0, length: 468
# Set to NaN 1/50 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_10_05'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 213
# Added coord *history_of_feedback | feedback=1.0, length: 213
# Set to NaN 5/24 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_13_03', 'LPFC_03_01', 'MCC_11_02', 'MCC_11_03', 'MCC_02_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 168
# Added coord *history_of_feedback | feedback=1.0, length: 168
# Set to NaN 6/64 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_06_02', 'LPFC_14_02', 'MCC_01_03', 'LPFC_13_03', 'MCC_16_01', 'MCC_09_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 293
# Added coord *history_of_feedback | feedback=1.0, length: 293
# Set to NaN 9/52 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_10_03', 'LPFC_14_01', 'MCC_05_02', 'MCC_11_02', 'MCC_06_03', 'LPFC_11_02', 'MCC_06_04', 'MCC_05_03', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 216
# Added coord *history_of_feedback | feedback=1.0, length: 216
# Set to NaN 15/33 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_07_01', 'MCC_07_02', 'LPFC_08_01', 'MCC_02_03', 'LPFC_09_02', 'MCC_06_01', 'MCC_02_01', 'MCC_04_01', 'LPFC_05_01', 'MCC_05_02', 'MCC_08_02', 'MCC_04_02', 'LPFC_12_01', 'MCC_09_02', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 130
# Added coord *history_of_feedback | feedback=1.0, length: 130
# Set to NaN 3/43 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_08_01', 'LPFC_14_02', 'LPFC_16_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 339
# Added coord *history_of_feedback | feedback=1.0, length: 339
# Set to NaN 25/40 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_09_05', 'MCC_04_04', 'LPFC_04_01', 'MCC_09_04', 'MCC_06_03', 'MCC_03_03', 'MCC_10_02', 'MCC_12_01', 'MCC_11_02', 'MCC_01_03', 'MCC_03_01', 'MCC_02_02', 'MCC_04_03', 'MCC_03_02', 'LPFC_04_03', 'MCC_04_01', 'LPFC_01_01', 'MCC_10_01', 'MCC_01_01', 'MCC_05_01', 'MCC_11_01', 'LPFC_04_02', 'LPFC_05_01', 'MCC_13_01', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 382
# Added coord *history_of_feedback | feedback=1.0, length: 382
# Set to NaN 13/43 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_10_02', 'LPFC_05_03', 'LPFC_16_01', 'LPFC_12_02', 'MCC_11_01', 'LPFC_05_01', 'MCC_11_05', 'MCC_03_01', 'MCC_10_01', 'MCC_08_01', 'MCC_05_03', 'LPFC_12_03', 'MCC_05_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 213
# Added coord *history_of_feedback | feedback=1.0, length: 213
# Set to NaN 15/38 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_14_01', 'MCC_07_03', 'MCC_13_03', 'MCC_07_02', 'MCC_03_04', 'LPFC_15_02', 'MCC_15_01', 'MCC_03_05', 'MCC_03_06', 'LPFC_15_01', 'MCC_11_04', 'MCC_02_04', 'MCC_03_03', 'LPFC_15_03', 'MCC_04_03'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 466
# Added coord *history_of_feedback | feedback=1.0, length: 466
# Set to NaN 35/59 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_10_02', 'LPFC_06_02', 'MCC_06_03', 'LPFC_06_05', 'LPFC_09_01', 'MCC_10_04', 'MCC_07_02', 'MCC_05_02', 'MCC_11_02', 'MCC_01_03', 'MCC_05_06', 'MCC_05_04', 'MCC_03_01', 'MCC_05_05', 'MCC_02_02', 'MCC_02_03', 'LPFC_14_01', 'MCC_02_01', 'MCC_09_03', 'MCC_01_01', 'MCC_05_01', 'LPFC_10_01', 'LPFC_12_02', 'MCC_10_03', 'MCC_07_03', 'LPFC_08_01', 'MCC_10_05', 'LPFC_10_03', 'MCC_08_03', 'LPFC_14_02', 'LPFC_12_01', 'LPFC_11_01', 'MCC_07_01', 'LPFC_06_06', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 251
# Added coord *history_of_feedback | feedback=1.0, length: 251
# Set to NaN 11/54 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_13_02', 'LPFC_15_02', 'LPFC_15_01', 'LPFC_14_01', 'LPFC_13_01', 'MCC_02_01', 'MCC_01_01', 'MCC_04_02', 'MCC_05_03', 'LPFC_12_03', 'LPFC_12_04'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 214
# Added coord *history_of_feedback | feedback=1.0, length: 214
# Set to NaN 21/45 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_07_04', 'MCC_10_04', 'MCC_01_03', 'LPFC_15_03', 'MCC_03_01', 'MCC_03_02', 'MCC_06_02', 'LPFC_04_03', 'MCC_04_02', 'MCC_09_03', 'MCC_01_01', 'MCC_01_04', 'LPFC_10_01', 'LPFC_04_02', 'LPFC_12_02', 'MCC_10_03', 'MCC_07_03', 'LPFC_08_01', 'LPFC_03_01', 'LPFC_11_01', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 336
# Added coord *history_of_feedback | feedback=1.0, length: 336
# Set to NaN 28/70 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_08_02', 'LPFC_16_05', 'MCC_04_04', 'MCC_04_05', 'LPFC_11_04', 'MCC_06_03', 'MCC_03_03', 'MCC_07_02', 'LPFC_08_03', 'MCC_05_02', 'LPFC_16_04', 'LPFC_16_03', 'MCC_01_03', 'MCC_03_01', 'MCC_04_03', 'MCC_03_02', 'MCC_02_01', 'MCC_04_01', 'MCC_04_02', 'MCC_05_03', 'MCC_14_03', 'MCC_05_01', 'MCC_01_04', 'LPFC_04_02', 'LPFC_12_02', 'MCC_14_02', 'MCC_07_01', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 170
# Added coord *history_of_feedback | feedback=1.0, length: 170
# Set to NaN 2/34 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_12_04', 'LPFC_13_01'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 87
# Added coord *history_of_feedback | feedback=1.0, length: 87
# Set to NaN 17/55 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'LPFC_16_01', 'LPFC_13_02', 'LPFC_16_02', 'MCC_06_02', 'LPFC_15_02', 'LPFC_15_01', 'LPFC_14_01', 'LPFC_11_04', 'MCC_06_03', 'LPFC_11_02', 'LPFC_11_03', 'LPFC_14_02', 'LPFC_15_03', 'LPFC_13_03', 'MCC_01_01', 'LPFC_06_01', 'LPFC_14_03'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 382
# Added coord *history_of_feedback | feedback=1.0, length: 382
# Set to NaN 18/47 units with trunctuated recordings, delay limit: 20 s.
#  Invalid units: {'MCC_03_02', 'MCC_10_03', 'MCC_07_03', 'MCC_16_01', 'MCC_02_03', 'LPFC_06_01', 'LPFC_06_02', 'MCC_11_04', 'LPFC_10_03', 'MCC_11_02', 'MCC_11_03', 'LPFC_02_01', 'LPFC_11_02', 'MCC_03_01', 'MCC_01_01', 'MCC_11_01', 'LPFC_10_04', 'MCC_01_02'}
# Built dataset, shape:
# Added coord *history_of_feedback | feedback=0.0, length: 383
# Added coord *history_of_feedback | feedback=1.0, length: 383
